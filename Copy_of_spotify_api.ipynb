# %% [markdown]
# <a href="https://colab.research.google.com/github/madamsapple/recentlyplayedspotify/blob/main/Copy_of_spotify_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install virtualenv
# Out:
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.10/dist-packages (20.27.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (3.16.1)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (4.3.6)

# %%
! virtualenv spotipy_virtlenv
# Out:
# created virtual environment CPython3.10.12.final.0-64 in 761ms
#   creator CPython3Posix(dest=/content/spotipy_virtlenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==24.3.1, setuptools==75.2.0, wheel==0.44.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
! source spotipy_virtlenv/bin/activate

# %%
! pip install spotipy --upgrade
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.10/dist-packages (2.24.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from spotipy) (5.2.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.2.3)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2024.8.30)

# %%
! pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.3.1)

# %%
! pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
# !ls /content
# Out:
# sample_data  spotipy_virtlenv

# %%
import os
import requests
import base64
import json
from dotenv import load_dotenv
from urllib.parse import urlencode

# Load credentials from .env file
load_dotenv()

# Access credentials
client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

redirect_uri = "https://www.example.com"  # Redirect URI you set in the Spotify Developer Dashboard

# Define the scopes you need
scopes = "user-read-recently-played"  # Example scopes for user data

# Function to get authorization URL
def get_authorization_url():
    auth_url = "https://accounts.spotify.com/authorize?" + urlencode({
        "client_id": client_id,
        "response_type": "code",
        "redirect_uri": redirect_uri,
        "scope": scopes
    })
    return auth_url

# Print authorization URL to get the code (user will log in and authorize)
print("Go to this URL to authorize the app:")
print(get_authorization_url())

# After user logs in, Spotify will redirect to redirect_uri with a code in the URL
# This code is obtained from the URL and passed to the next function

# Function to exchange the authorization code for an access token
def get_token(auth_code):
    url = "https://accounts.spotify.com/api/token"

    # Encode client credentials for Basic Authorization
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")

    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }

    data = {
        "grant_type": "authorization_code",
        "code": auth_code,
        "redirect_uri": redirect_uri
    }

    result = requests.post(url, headers=headers, data=data)

    # Convert the resulting JSON string data containing the access token
    json_result = json.loads(result.content)

    # Extract the token
    token = json_result.get("access_token")
    return token

# Get the token after the user provides the authorization code
auth_code = input("Enter the authorization code from the URL: ")
token = get_token(auth_code)
print("Access Token:", token)

print()
# Out:
# Go to this URL to authorize the app:
# https://accounts.spotify.com/authorize?client_id=ca83c539ed7d45cfb1fbf009cc56a1f3&response_type=code&redirect_uri=https%3A%2F%2Fwww.example.com&scope=user-read-recently-played
# Enter the authorization code from the URL: AQAK5bsj-PIodimTlCghIT-t8hXT8ml36TA2KvBHAW3nP9NY5qr-aPVO0PSKfvi2snCBF0tqj2zrAcxk7lsM7BP3rGijDPwHpkHl-DeAKQBDEhGzyORCYQZIihT4JMEXfZE-De-8tq2SrISouhW3ip7XiWlYWZtbUG8nAuwSsRQgH_OzR7HtNzUUdmWrRsp_Fk4nx1Xg
# Access Token: BQDdWk-0h_-9NwWFw5qETAkqQyUAk9oZA3xMWZnknZziIlICVKDMM1NIUOf841eZsSPxx9fajbiRmzX_GCpqjWC-2II1txuqeTr0MDT-WOwVFfnKv0GkQEdhG46zJTQ18WVvP6CGbAU1SQ3lQ3XhzmC7eUrZ-6JVLM0WCwXHxRRy4mvC1_KMJZ3s3eeAmBFlBm8SbplgK4PXMbzEFhQ

# %%
#getting all top 50 tracks
top50_url = "https://api.spotify.com/v1/me/player/recently-played?limit=50"
headers = get_auth_header(token)

result = requests.get(top50_url, headers = headers)
json_result = json.loads(result.content)

print(json_result)
# Out:
# {'items': [{'track': {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63XBtGSEZINSyXylZxEUbv'}, 'href': 'https://api.spotify.com/v1/artists/63XBtGSEZINSyXylZxEUbv', 'id': '63XBtGSEZINSyXylZxEUbv', 'name': 'Victoria Monét', 'type': 'artist', 'uri': 'spotify:artist:63XBtGSEZINSyXylZxEUbv'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6aW67R0sshdUwtbJEG2uQR'}, 'href': 'https://api.spotify.com/v1/albums/6aW67R0sshdUwtbJEG2uQR', 'id': '6aW67R0sshdUwtbJEG2uQR', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27350aa87e1dea05ba3155bbbb2', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0250aa87e1dea05ba3155bbbb2', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485150aa87e1dea05ba3155bbbb2', 'width': 64}], 'name': 'JAGUAR', 'release_date': '2020-08-07', 'release_date_precision': 'day', 'total_tracks': 9, 'type': 'album', 'uri': 'spotify:album:6aW67R0sshdUwtbJEG2uQR'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63XBtGSEZINSyXylZxEUbv'}, 'href': 'https://api.spotify.com/v1/artists/63XBtGSEZINSyXylZxEUbv', 'id': '63XBtGSEZINSyXylZxEUbv', 'name': 'Victoria Monét', 'type': 'artist', 'uri': 'spotify:artist:63XBtGSEZINSyXylZxEUbv'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 220207, 'explicit': True, 'external_ids': {'isrc': 'US23A1501560'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6YQmDvj6XVAKSPLzjjLrFj'}, 'href': 'https://api.spotify.com/v1/tracks/6YQmDvj6XVAKSPLzjjLrFj', 'id': '6YQmDvj6XVAKSPLzjjLrFj', 'is_local': False, 'name': 'Ass Like That', 'popularity': 54, 'preview_url': 'https://p.scdn.co/mp3-preview/338fc2a95bd ...

# %%
import csv

# Your JSON data (shortened for clarity)
data = json_result

# Specify CSV file name
csv_file = "spotify_tracks.csv"

# Open CSV file for writing
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["Track Name", "Artist", "Album Name", "Release Date", "Track URL", "Album URL", "Played At"])
    writer.writeheader()

    # Loop through the JSON data and write each entry
    for item in data["items"]:
        track_info = item["track"]
        artist_name = track_info["artists"][0]["name"]
        album_name = track_info["album"]["name"]
        release_date = track_info["album"]["release_date"]
        track_url = track_info["external_urls"]["spotify"]
        album_url = track_info["album"]["external_urls"]["spotify"]
        played_at = item["played_at"]

        writer.writerow({
            "Track Name": track_info["name"],
            "Artist": artist_name,
            "Album Name": album_name,
            "Release Date": release_date,
            "Track URL": track_url,
            "Album URL": album_url,
            "Played At": played_at
        })

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
#getting track name and id from the first result as an example/test

id = json_result["items"][0]['track']['id']
name = json_result["items"][0]['track']['name']

print("Track Title: " + name + ",  Track ID: " + id)
# Out:
# Track Title: Ella Baila Sola,  Track ID: 3qQbCzHBycnDpGskqOWY0E

# %%
#Let's get the IDs of all 50 tracks. These IDs will help us fetch the audio
#features of them all.
#I first printed the IDs to test if it's working and see how it looks, and then I decided to create
#a dictionary which would store keys as int indices and values as IDs.

#I chose a dictionary to store the values so that I could conveniently add them to my url using
#string formatting. This smoothly automates the action of adding the IDs as queries to my url,
#while doing an audio feature request.

index = 0
IDs = {}

for x in json_result['items']:
    print(x['track']['id'])

    #starting from 0, add each increasing index and its corrresponding ID string to the dictionary
    IDs.update({index: x['track']['id']})
    index += 1


#print the ID dictionary
print(IDs)





#url = https://api.spotify.com/v1/audio-features?ids={7ouMYWpwJ422jRcDASZB7P%}2C4VqPOruhp5EdPBeR92t6lQ%2C2takcwOaAZWiXQijPHIx7B'

#url = https://api.spotify.com/v1/audio-features?ids=7ouMYWpwJ422jRcDASZB7P%2C4VqPOruhp5EdPBeR92t6lQ%2C2takcwOaAZWiXQijPHIx7B'
# Out:
# 3qQbCzHBycnDpGskqOWY0E
# 5AqiaZwhmC6dIbgWrD5SzV
# 7ro0hRteUMfnOioTFI5TG1
# 2UW7JaomAMuX9pZrjVpHAU
# 6pD0ufEQq0xdHSsRbg9LBK
# 4DHcnVTT87F0zZhRPYmZ3B
# 2FDTHlrBguDzQkp7PVj16Q
# 7FbrGaHYVDmfr7KoLIZnQ7
# 4Dvkj6JhhA12EX05fT7y2e
# 1odExI7RdWc4BT515LTAwj
# 1Qrg8KqiBpW07V7PNxwwwL
# 5IAESfJjmOYu7cHyX557kz
# 368eeEO3Y2uZUQ6S5oIjcu
# 5rurggqwwudn9clMdcchxT
# 1BxfuPKGuaTgP7aM0Bbdwr
# 6XSqqQIy7Lm7SnwxS4NrGx
# 0RiRZpuVRbi7oqRdSMwhQY
# 1s7oOCT8vauUh01PbJD6ps
# 0DWdj2oZMBFSzRsi2Cvfzf
# 2dHHgzDwk4BJdRwy9uXhTO
# 5XeFesFbtLpXzIVDNQP22n
# 1Hs1uUl8o2VtDp1DABFq0O
# 7KA4W4McWYRpgf0fWsJZWB
# 39MK3d3fonIP8Mz9oHCTBB
# 1daDRI9ahBonbWD8YcxOIB
# 4PA1wK0leCjmRZlP5dQ8Lv
# 3Ua0m0YmEjrMi9XErKcNiR
# 0V3wPSX9ygBnCm8psDIegu
# 609E1JCInJncactoMmkDon
# 6Ec5LeRzkisa5KJtwLfOoW
# 4uUG5RXrOk84mYEfFvj3cK
# 1haJsMtoBhHfvuM7XWuT3W
# 7K3BhSpAxZBznislvUMVtn
# 4W4fNrZYkobj539TOWsLO2
# 2LBqCSwhJGcFQeTHMVGwy3
# 4FAKtPVycI4DxoOHC01YqD
# 3USxtqRwSYz57Ewm6wWRMp
# 6GGtHZgBycCgGBUhZo81xe
# 7MXVkk9YMctZqd1Srtv4MB
# 4h9wh7iOZ0GGn8QVp4RAOB
# 6T7FXSuXykeGktMLGp8WgE
# 26b3oVLrRUaaybJulow9kz
# 1vYXt7VSjH9JIM5oRRo7vA
# 0JmnkIqdlnUzPaf8sqBRs3
# 3JvKfv6T31zO0ini8iNItO
# 2mpoNBkngUEwnaKoBhZ0vl
# 1vvcEHQdaUTvWt0EIUYcFK
# 6AQbmUe0Qwf5PZnt4HmTXv
# 1p80LdxRV74UKvL8gnD7ky
# 6n2P81rPk2RTzwnNNgFOdb
# {0: '3qQbCzHBycnDpGskqOWY0E', 1: '5AqiaZwhmC6dIbgWrD5SzV', 2: '7ro0hRteUMfnOioTFI5TG1', 3: '2UW7JaomAMuX9pZrjVpHAU', 4: '6pD0ufEQq0xdHSsRbg9LBK', 5: '4DHcnVTT87F0zZhRPYmZ3B', 6: '2FDTHlrBguDzQkp7PVj16Q', 7: '7FbrGaHYVDmfr7KoLIZnQ7', 8: '4Dvkj6JhhA12EX05fT7y2e', 9: '1odExI7RdWc4BT515LTAwj', 10: '1Qrg8KqiBpW07V7PNxwwwL', 11: '5IAESfJjmOYu7cHyX557kz', 12: '368eeEO3Y2uZUQ6S5oIjcu', 13: '5rurggqwwudn9clMdcchxT', 14: '1BxfuPKGuaTgP7aM0Bbdwr', 15: '6XSqqQIy7Lm7SnwxS4NrGx', 16: '0RiRZpuVRbi7oqRdSMwhQY', 17: '1s7oOCT8vauUh01PbJD6ps', 18: '0DWdj2oZMBFSzRsi2Cvfzf', 19: '2dHHgzDwk4BJdRwy9uXhTO', 20: '5XeFesFbtLpXzIVDNQP22n', 21: '1Hs1uUl8o2VtDp1DABFq0O', 22: '7KA4W4McWYRpgf0fWsJZWB', 23: '39MK3d3fonIP8Mz9oHCTBB', 24: '1daDRI9ahBonbWD8YcxOIB', 25: '4PA1wK0leCjmRZlP5dQ8Lv', 26: '3Ua0m0YmEjrMi9XErKcNiR', 27: '0V3wPSX9ygBnCm8psDIegu', 28: '609E1JCInJncactoMmkDon', 29: '6Ec5LeRzkisa5KJtwLfOoW', 30: '4uUG5RXrOk84mYEfFvj3cK', 31: '1haJsMtoBhHfvuM7XWuT3W', 32: '7K3BhSpAxZBznislvUMVtn', 33: '4W4fNrZYkobj539TOWsLO2', 34: '2LBqCSwhJGcFQeTHMVGwy3', 35: '4FAKtPVycI4DxoOHC01YqD', 36: '3USxtqRwSYz57Ewm6wWRMp', 37: '6GGtHZgBycCgGBUhZo81xe', 38: '7MXVkk9YMctZqd1Srtv4MB', 39: '4h9wh7iOZ0GGn8QVp4RAOB', 40: '6T7FXSuXykeGktMLGp8WgE', 41: '26b3oVLrRUaaybJulow9kz', 42: '1vYXt7VSjH9JIM5oRRo7vA', 43: '0JmnkIqdlnUzPaf8sqBRs3', 44: '3JvKfv6T31zO0ini8iNItO', 45: '2mpoNBkngUEwnaKoBhZ0vl', 46: '1vvcEHQdaUTvWt0EIUYcFK', 47: '6AQbmUe0Qwf5PZnt4HmTXv', 48: '1p80LdxRV74UKvL8gnD7ky', 49: '6n2P81rPk2RTzwnNNgFOdb'}

# %%
#url = https://api.spotify.com/v1/audio-features?ids={7ouMYWpwJ422jRcDASZB7P%}2C4VqPOruhp5EdPBeR92t6lQ%2C2takcwOaAZWiXQijPHIx7B
features_url = "https://api.spotify.com/v1/audio-features?ids="

# for x in range(49):
#     url += ("{" + str(x) + "}")

#     if x == 48:
#         url += "{49}"


# print(url)

# %%
#adding all the IDs to the url for the request
for x in IDs:

    #if it is the last item
    #don't add the comma and just exit the loop
    if x == 49:
        features_url += IDs[x]
        break

    #realised we needed commas instead of %
    features_url += IDs[x] + ','



print(features_url)
# Out:
# https://api.spotify.com/v1/audio-features?ids=3qQbCzHBycnDpGskqOWY0E,5AqiaZwhmC6dIbgWrD5SzV,7ro0hRteUMfnOioTFI5TG1,2UW7JaomAMuX9pZrjVpHAU,6pD0ufEQq0xdHSsRbg9LBK,4DHcnVTT87F0zZhRPYmZ3B,2FDTHlrBguDzQkp7PVj16Q,7FbrGaHYVDmfr7KoLIZnQ7,4Dvkj6JhhA12EX05fT7y2e,1odExI7RdWc4BT515LTAwj,1Qrg8KqiBpW07V7PNxwwwL,5IAESfJjmOYu7cHyX557kz,368eeEO3Y2uZUQ6S5oIjcu,5rurggqwwudn9clMdcchxT,1BxfuPKGuaTgP7aM0Bbdwr,6XSqqQIy7Lm7SnwxS4NrGx,0RiRZpuVRbi7oqRdSMwhQY,1s7oOCT8vauUh01PbJD6ps,0DWdj2oZMBFSzRsi2Cvfzf,2dHHgzDwk4BJdRwy9uXhTO,5XeFesFbtLpXzIVDNQP22n,1Hs1uUl8o2VtDp1DABFq0O,7KA4W4McWYRpgf0fWsJZWB,39MK3d3fonIP8Mz9oHCTBB,1daDRI9ahBonbWD8YcxOIB,4PA1wK0leCjmRZlP5dQ8Lv,3Ua0m0YmEjrMi9XErKcNiR,0V3wPSX9ygBnCm8psDIegu,609E1JCInJncactoMmkDon,6Ec5LeRzkisa5KJtwLfOoW,4uUG5RXrOk84mYEfFvj3cK,1haJsMtoBhHfvuM7XWuT3W,7K3BhSpAxZBznislvUMVtn,4W4fNrZYkobj539TOWsLO2,2LBqCSwhJGcFQeTHMVGwy3,4FAKtPVycI4DxoOHC01YqD,3USxtqRwSYz57Ewm6wWRMp,6GGtHZgBycCgGBUhZo81xe,7MXVkk9YMctZqd1Srtv4MB,4h9wh7iOZ0GGn8QVp4RAOB,6T7FXSuXykeGktMLGp8WgE,26b3oVLrRUaaybJulow9kz,1vYXt7VSjH9JIM5oRRo7vA,0JmnkIqdlnUzPaf8sqBRs3,3JvKfv6T31zO0ini8iNItO,2mpoNBkngUEwnaKoBhZ0vl,1vvcEHQdaUTvWt0EIUYcFK,6AQbmUe0Qwf5PZnt4HmTXv,1p80LdxRV74UKvL8gnD7ky,6n2P81rPk2RTzwnNNgFOdb

# %%
#making request for audio features of all our top 50 tracks
ft_results = requests.get(features_url, headers = headers)
features = json.loads(ft_results.content)

print(features)
# Out:
# {'audio_features': [{'danceability': 0.668, 'energy': 0.758, 'key': 5, 'loudness': -5.176, 'mode': 0, 'speechiness': 0.0332, 'acousticness': 0.483, 'instrumentalness': 1.89e-05, 'liveness': 0.0837, 'valence': 0.834, 'tempo': 147.989, 'type': 'audio_features', 'id': '3qQbCzHBycnDpGskqOWY0E', 'uri': 'spotify:track:3qQbCzHBycnDpGskqOWY0E', 'track_href': 'https://api.spotify.com/v1/tracks/3qQbCzHBycnDpGskqOWY0E', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qQbCzHBycnDpGskqOWY0E', 'duration_ms': 165671, 'time_signature': 3}, {'danceability': 0.854, 'energy': 0.668, 'key': 5, 'loudness': -7.848, 'mode': 0, 'speechiness': 0.0466, 'acousticness': 0.264, 'instrumentalness': 5.61e-05, 'liveness': 0.117, 'valence': 0.805, 'tempo': 132.966, 'type': 'audio_features', 'id': '5AqiaZwhmC6dIbgWrD5SzV', 'uri': 'spotify:track:5AqiaZwhmC6dIbgWrD5SzV', 'track_href': 'https://api.spotify.com/v1/tracks/5AqiaZwhmC6dIbgWrD5SzV', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AqiaZwhmC6dIbgWrD5SzV', 'duration_ms': 187660, 'time_signature': 3}, {'danceability': 0.652, 'energy': 0.8, 'key': 9, 'loudness': -4.019, 'mode': 0, 'speechiness': 0.0614, 'acousticness': 0.143, 'instrumentalness': 0.629, 'liveness': 0.112, 'valence': 0.234, 'tempo': 143.978, 'type': 'audio_features', 'id': '7ro0hRteUMfnOioTFI5TG1', 'uri': 'spotify:track:7ro0hRteUMfnOioTFI5TG1', 'track_href': 'https://api.spotify.com/v1/tracks/7ro0hRteUMfnOioTFI5TG1', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ro0hRteUMfnOioTFI5TG1', 'duration_ms': 231704, 'time_signature': 4}, {'danceability': 0.812, 'energy': 0.479, 'key': 2, 'loudness': -5.678, 'mode': 0, 'speechiness': 0.333, 'acousticness': 0.213, 'instrumentalness': 1.21e-06, 'liveness': 0.0756, 'valence': 0.559, 'tempo': 169.922, 'type': 'audio_features', 'id': '2UW7JaomAMuX9pZrjVpHAU', 'uri': 'spotify:track:2UW7JaomAMuX9pZrjVpHAU', 'track_href': 'https://api.spotify.com/v1/tracks/2UW7JaomAMuX9pZrjVpHAU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UW7JaomAMuX9pZrjVpHAU', 'duration_ms': 234353, 'time_signature': 4}, {'danceability': 0.569, 'energy': 0.724, 'key': 6, 'loudness': -4.076, 'mode': 0, 'speechiness': 0.0474, 'acousticness': 0.228, 'instrumentalness': 0, 'liveness': 0.27, 'valence': 0.562, 'tempo': 83.118, 'type': 'audio_features', 'id': '6pD0ufEQq0xdHSsRbg9LBK', 'uri': 'spotify:track:6pD0ufEQq0xdHSsRbg9LBK', 'track_href': 'https://api.spotify.com/v1/tracks/6pD0ufEQq0xdHSsRbg9LBK', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pD0ufEQq0xdHSsRbg9LBK', 'duration_ms': 194563, 'time_signature': 4}, {'danceability': 0.707, 'energy': 0.681, 'key': 0, 'loudness': -4.325, 'mode': 1, 'speechiness': 0.0668, 'acousticness': 0.0632, 'instrumentalness': 5.15e-06, 'liveness': 0.0322, 'valence': 0.646, 'tempo': 117.999, 'type': 'audio_features', 'id': '4DHcnVTT87F0zZhRPYmZ3B', 'uri': 'spotify:track:4DHcnVTT87F0zZhRPYmZ3B', 'track_href': 'https://api.spotify.com/v1/tracks/4DHcnVTT87F0zZhRPYmZ3B', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DHcnVTT87F0zZhRPYmZ3B', 'duration_ms': 200455, 'time_signature': 4}, {'danceability': 0.916, 'energy': 0.583, 'key': 1, 'loudness': -8.067, 'mode': 1, 'speechiness': 0.241, 'acousticness': 0.186, 'instrumentalness': 0, 'liveness': 0.0798, 'valence': 0.661, 'tempo': 141.095, 'type': 'audio_features', 'id': '2FDTHlrBguDzQkp7PVj16Q', 'uri': 'spotify:track:2FDTHlrBguDzQkp7PVj16Q', 'track_href': 'https://api.spotify.com/v1/tracks/2FDTHlrBguDzQkp7PVj16Q', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FDTHlrBguDzQkp7PVj16Q', 'duration_ms': 226383, 'time_signature': 4}, {'danceability': 0.783, 'energy': 0.592, 'key': 11, 'loudness': -8.332, 'mode': 0, 'speechiness': 0.0331, 'acousticness': 0.435, 'instrumentalness': 4.15e-06, 'liveness': 0.347, 'valence': 0.726, 'tempo': 120.018, 'type': 'audio_features', 'id': '7FbrGaHYVDmfr7KoLIZnQ7', 'uri': 'spotify:track:7FbrGaHYVDmfr7KoLIZnQ7', 'track_href': 'https://api.spoti ...

# %%
# valence
# number [float]
# A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track.
# Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric),
# while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# Example value: 0.428
# Range: 0 - 1

# I will use this valence value to determine the mood. I will print out all the
# top 50 tracks' valence now

valences = []
for x in features['audio_features']:
    print(x['valence'])
    valences.append(x['valence'])
# Out:
# 0.834
# 0.805
# 0.234
# 0.559
# 0.562
# 0.646
# 0.661
# 0.726
# 0.662
# 0.324
# 0.418
# 0.566
# 0.963
# 0.22
# 0.564
# 0.672
# 0.925
# 0.811
# 0.607
# 0.172
# 0.479
# 0.634
# 0.62
# 0.204
# 0.494
# 0.169
# 0.362
# 0.533
# 0.53
# 0.134
# 0.304
# 0.844
# 0.478
# 0.506
# 0.508
# 0.58
# 0.531
# 0.166
# 0.486
# 0.825
# 0.733
# 0.693
# 0.775
# 0.896
# 0.131
# 0.893
# 0.277
# 0.857
# 0.583
# 0.7

# %%
valences
# Out:
# [0.834,
#  0.805,
#  0.234,
#  0.559,
#  0.562,
#  0.646,
#  0.661,
#  0.726,
#  0.662,
#  0.324,
#  0.418,
#  0.566,
#  0.963,
#  0.22,
#  0.564,
#  0.672,
#  0.925,
#  0.811,
#  0.607,
#  0.172,
#  0.479,
#  0.634,
#  0.62,
#  0.204,
#  0.494,
#  0.169,
#  0.362,
#  0.533,
#  0.53,
#  0.134,
#  0.304,
#  0.844,
#  0.478,
#  0.506,
#  0.508,
#  0.58,
#  0.531,
#  0.166,
#  0.486,
#  0.825,
#  0.733,
#  0.693,
#  0.775,
#  0.896,
#  0.131,
#  0.893,
#  0.277,
#  0.857,
#  0.583,
#  0.7]
